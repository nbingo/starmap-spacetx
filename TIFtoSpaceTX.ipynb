# %% [markdown]
# ## Export data to SpaceTX format
#
# First create the subclasses of `FetchedTile` and `TileFetcher` required and then export the data into SpaceTX

# %%
# %load_ext autoreload
# %autoreload 2

import functools
import os
from typing import Mapping, Tuple, Union

import click
import numpy as np
from skimage.io import imread
from slicedimage import ImageFormat

from starfish import Codebook
from starfish.experiment.builder import FetchedTile, TileFetcher, write_experiment_json
from starfish.types import Axes, Coordinates, CoordinateValue, Features

import pdb

@functools.lru_cache(maxsize=1)
def cached_read_fn(file_path) -> np.ndarray:
    return imread(file_path)

class StarMapTile(FetchedTile):

    def __init__(
            self,
            file_path: str,
            coordinates: Mapping[Union[str, Coordinates], CoordinateValue]
    ) -> None:
        self.file_path = file_path
        self._coordinates = coordinates

    @property
    def shape(self) -> Mapping[Axes, int]:
        print(np.shape(self.tile_data()))
#         return {Axes.Y: 7962, Axes.X: 3356}
        return {Axes.Y: 4000, Axes.X: 800}

    @property
    def coordinates(self) -> Mapping[Union[str, Coordinates], CoordinateValue]:
        return self._coordinates

    @staticmethod
    def crop(img) -> np.ndarray:
        crp = img[2000:6000, 1000:1800]
        return crp
    
    def tile_data(self) -> np.ndarray:
        return self.crop(imread(self.file_path))
    
    def __str__(self) -> str:
        return self.file_path
    
class StarMapTileFetcher(TileFetcher):
    
    def __init__(self, input_dir: str) -> None:
        self.input_dir = input_dir
#         self.num_z = 11
        
    def get_tile(
            self, fov_id: int, round_label: int, ch_label: int, zplane_label: int) -> FetchedTile:
        if zplane_label < 10:
            zplane_padded = f"00{zplane_label}"
        elif zplane_label < 100:
            zplane_padded = f"0{zplane_label}"
        else:
            zplane_padded = str(zplane_label)
        basename = f"2019-06-29_Justus_section3_round{round_label+1}_2x10_1_FusionStitcher_C{ch_label+1}_Z{zplane_padded}.tif"  # translate to 3d
        file_path = os.path.join(self.input_dir, basename)
        coordinates = {
            Coordinates.X: (0.0, 0.0001),
            Coordinates.Y: (0.0, 0.0001),
            Coordinates.Z: (0.0, 0.0001),
        }
        return StarMapTile(file_path, coordinates)
    
class StarMapDAPITileFetcher(TileFetcher):
    
    def __init__(self, input_dir: str) -> None:
        self.input_dir = input_dir
        
    def get_tile(
            self, fov_id: int, round_label: int, ch_label: int, zplane_label: int) -> FetchedTile:
        if zplane_label < 10:
            zplane_padded = f"00{zplane_label}"
        elif zplane_label < 100:
            zplane_padded = f"0{zplane_label}"
        else:
            zplane_padded = str(zplane_label)
        basename = f"2019-06-29_Justus_section3_round{round_label+1}_2x10_1_FusionStitcher_C{ch_label}_Z{zplane_padded}.tif"
        file_path = os.path.join(self.input_dir, basename)
        coordinates = {
            Coordinates.X: (0.0, 0.0001),
            Coordinates.Y: (0.0, 0.0001),
            Coordinates.Z: (0.0, 0.0001),
        }
        return StarMapTile(file_path, coordinates)
    
def format_data(input_dir, output_dir):
    
    primary_image_dimensions: Mapping[Axes, int] = {
        Axes.ROUND: 1,
        Axes.CH: 4,
        Axes.ZPLANE: 11,
    }
    
    aux_image_dimensions: Mapping[str, Mapping[Union[str, Axes], int]] = {
        "nuclei": {
            Axes.ROUND: 1,
            Axes.CH: 1,
            Axes.ZPLANE: 11
        }
    }
    
#     pdb.set_trace()
    write_experiment_json(
        path=output_dir,
        fov_count=1,
        tile_format=ImageFormat.TIFF,
        primary_image_dimensions=primary_image_dimensions,
        aux_name_to_dimensions=aux_image_dimensions,
        primary_tile_fetcher=StarMapTileFetcher(input_dir),
        aux_tile_fetcher={"nuclei": StarMapDAPITileFetcher(input_dir)},
        dimension_order=(Axes.ROUND, Axes.CH, Axes.ZPLANE)
    )
    
    codebook = [
        {
            Features.CODEWORD: [
                {Axes.ROUND.value: 0, Axes.CH.value: 0, Features.CODE_VALUE: 1}
            ],
            Features.TARGET: "GFP"
        },
        {
            Features.CODEWORD: [
                {Axes.ROUND.value: 0, Axes.CH.value: 1, Features.CODE_VALUE: 1}
            ],
            Features.TARGET: "RFP"
        },
        {
            Features.CODEWORD: [
                {Axes.ROUND.value: 0, Axes.CH.value: 2, Features.CODE_VALUE: 1}
            ],
            Features.TARGET: "Cy5"
        },
        {
            Features.CODEWORD: [
                {Axes.ROUND.value: 0, Axes.CH.value: 3, Features.CODE_VALUE: 1}
            ],
            Features.TARGET: "iRFP"
        }
    ]
    Codebook.from_code_array(codebook).to_json("/home/nomi/Desktop/starfish/experiment/codebook.json")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2

import functools
import os
from typing import Mapping, Tuple, Union

import click
import numpy as np
from skimage.io import imread
from slicedimage import ImageFormat

from starfish import Codebook
from starfish.experiment.builder import FetchedTile, TileFetcher, write_experiment_json
from starfish.types import Axes, Coordinates, CoordinateValue, Features

import pdb

@functools.lru_cache(maxsize=1)
def cached_read_fn(file_path) -> np.ndarray:
    return imread(file_path)

class StarMapTile(FetchedTile):

    def __init__(
            self,
            file_path: str,
            coordinates: Mapping[Union[str, Coordinates], CoordinateValue]
    ) -> None:
        self.file_path = file_path
        self._coordinates = coordinates

    @property
    def shape(self) -> Mapping[Axes, int]:
        print(np.shape(self.tile_data()))
#         return {Axes.Y: 7962, Axes.X: 3356}
        return {Axes.Y: 4000, Axes.X: 800}

    @property
    def coordinates(self) -> Mapping[Union[str, Coordinates], CoordinateValue]:
        return self._coordinates

    @staticmethod
    def crop(img) -> np.ndarray:
        crp = img[2000:6000, 1000:1800]
        return crp
    
    def tile_data(self) -> np.ndarray:
        return self.crop(imread(self.file_path))
    
    def __str__(self) -> str:
        return self.file_path
    
class StarMapTileFetcher(TileFetcher):
    
    def __init__(self, input_dir: str) -> None:
        self.input_dir = input_dir
#         self.num_z = 11
        
    def get_tile(
            self, fov_id: int, round_label: int, ch_label: int, zplane_label: int) -> FetchedTile:
        if zplane_label < 10:
            zplane_padded = f"00{zplane_label}"
        elif zplane_label < 100:
            zplane_padded = f"0{zplane_label}"
        else:
            zplane_padded = str(zplane_label)
        basename = f"2019-06-29_Justus_section3_round{round_label+1}_2x10_1_FusionStitcher_C2_Z{zplane_padded}.tif"  # translate to 3d
        file_path = os.path.join(self.input_dir, basename)
        coordinates = {
            Coordinates.X: (0.0, 0.0001),
            Coordinates.Y: (0.0, 0.0001),
            Coordinates.Z: (0.0, 0.0001),
        }
        return StarMapTile(file_path, coordinates)
    
class StarMapDAPITileFetcher(TileFetcher):
    
    def __init__(self, input_dir: str) -> None:
        self.input_dir = input_dir
        
    def get_tile(
            self, fov_id: int, round_label: int, ch_label: int, zplane_label: int) -> FetchedTile:
        if zplane_label < 10:
            zplane_padded = f"00{zplane_label}"
        elif zplane_label < 100:
            zplane_padded = f"0{zplane_label}"
        else:
            zplane_padded = str(zplane_label)
        basename = f"2019-06-29_Justus_section3_round{round_label+1}_2x10_1_FusionStitcher_C{ch_label}_Z{zplane_padded}.tif"
        file_path = os.path.join(self.input_dir, basename)
        coordinates = {
            Coordinates.X: (0.0, 0.0001),
            Coordinates.Y: (0.0, 0.0001),
            Coordinates.Z: (0.0, 0.0001),
        }
        return StarMapTile(file_path, coordinates)
    
def format_data(input_dir, output_dir):
    
    primary_image_dimensions: Mapping[Axes, int] = {
        Axes.ROUND: 1,
        Axes.CH: 1,
        Axes.ZPLANE: 11,
    }
    
    aux_image_dimensions: Mapping[str, Mapping[Union[str, Axes], int]] = {
        "nuclei": {
            Axes.ROUND: 1,
            Axes.CH: 1,
            Axes.ZPLANE: 11
        }
    }
    
#     pdb.set_trace()
    write_experiment_json(
        path=output_dir,
        fov_count=1,
        tile_format=ImageFormat.TIFF,
        primary_image_dimensions=primary_image_dimensions,
        aux_name_to_dimensions=aux_image_dimensions,
        primary_tile_fetcher=StarMapTileFetcher(input_dir),
        aux_tile_fetcher={"nuclei": StarMapDAPITileFetcher(input_dir)},
        dimension_order=(Axes.ROUND, Axes.CH, Axes.ZPLANE)
    )
    codebook = [
        {
            Features.CODEWORD: [
                {Axes.ROUND.value: 0, Axes.CH.value: 0, Features.CODE_VALUE: 1}
            ],
            Features.TARGET: "RFP"
        }
    ]
    Codebook.from_code_array(codebook).to_json("/home/nomi/Desktop/starfish/experiment/codebook.json")

# %%
format_data("/home/nomi/Desktop/starfish/raw_data/2019-06-29_Justus_section3_round1_2x10_1",
           "/home/nomi/Desktop/starfish/experiment")
# Out:
# (4000, 800)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/skimage/io/_io.py:141: UserWarning: <_io.BytesIO object at 0x7f6d16b30f68> is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/skimage/io/_io.py:141: UserWarning: <_io.BytesIO object at 0x7f6d16766570> is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/skimage/io/_io.py:141: UserWarning: <_io.BytesIO object at 0x7f6d16766620> is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/skimage/io/_io.py:141: UserWarning: <_io.BytesIO object at 0x7f6d16766678> is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/skimage/io/_io.py:141: UserWarning: <_io.BytesIO object at 0x7f6d167666d0> is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/skimage/io/_io.py:141: UserWarning: <_io.BytesIO object at 0x7f6d16766728> is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/skimage/io/_io.py:141: UserWarning: <_io.BytesIO object at 0x7f6d16766780> is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/skimage/io/_io.py:141: UserWarning: <_io.BytesIO object at 0x7f6d167667d8> is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/skimage/io/_io.py:141: UserWarning: <_io.BytesIO object at 0x7f6d16766830> is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/skimage/io/_io.py:141: UserWarning: <_io.BytesIO object at 0x7f6d16766888> is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/skimage/io/_io.py:141: UserWarning: <_io.BytesIO object at 0x7f6d167668e0> is a low contrast image
#   warn('%s is a low contrast image' % fname)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# (4000, 800)
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/skimage/io/_io.py:141: UserWarning: <_io.BytesIO object at 0x7f6d167669e8> is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/skimage/io/_io.py:141: UserWarning: <_io.BytesIO object at 0x7f6d16b30fc0> is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/skimage/io/_io.py:141: UserWarning: <_io.BytesIO object at 0x7f6d167665c8> is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %% [markdown]
# ## Load the experiment and visualize the codebook
# Possibly necessary to copy the codebook information from `codebook_backup.json`.

# %%
# %load_ext autoreload
# %autoreload 2
from starfish import Experiment
from six.moves import urllib
from slicedimage.backends import CachingBackend, DiskBackend, HttpBackend, SIZE_LIMIT

baseurl="/home/nomi/Desktop/starfish/experiment/experiment.json"
experiment = Experiment.from_json(baseurl)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
experiment.codebook
# Out:
# <xarray.Codebook (target: 1, c: 1, r: 1)>
# array([[[1]]], dtype=uint8)
# Coordinates:
#   * target   (target) object 'RFP'
#   * c        (c) int64 0
#   * r        (r) int64 0

# %% [markdown]
# ## Visualize the FOV

# %%
fov = experiment["fov_000"]

# %%
image = fov.get_image("primary")
# Out:
# 100%|██████████| 11/11 [00:00<00:00, 23.53it/s]

# %%
import starfish
# %gui qt
ipython = get_ipython()
ipython.magic("gui qt5")
starfish.display(image)

# %% [markdown]
# ## Project onto the Z axis and clip
# The slider in the viewer should now only have as many options as there are channels. Also clipping the image to remove background noise.

# %%
import starfish
clipper = starfish.image.Filter.Clip(p_min=97)
z_proj: starfish.ImageStack = clipper.run(image.max_proj(Axes.ZPLANE))
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 109.00it/s]

# %%
starfish.display(z_proj)

# %% [markdown]
# Find spots
# ----------
# Finally, a local blob detector that finds spots in each (z, y, x) volume
# separately is applied. The user selects an "anchor round" and spots found in
# all channels of that round are used to seed a local search across other rounds
# and channels. The closest spot is selected, and any spots outside the search
# radius (here 10 pixels) is discarded.
#
# The Spot finder returns an IntensityTable containing all spots from round
# zero. Note that many of the spots do _not_ identify spots in other rounds and
# channels and will therefore fail decoding. Because of the stringency built
# into the STARmap codebook, it is OK to be relatively permissive with the spot
# finding parameters for this assay.

# %%
import starfish
lsbd = starfish.spots.DetectSpots.BlobDetector(
    min_sigma=.5,
    max_sigma=8,
    num_sigma=50,
    threshold=np.percentile(np.ravel(z_proj.xarray.values), 95),
#     exclude_border=2,
#     anchor_round=0,
#     search_radius=10,
)
tlmpf = starfish.spots.DetectSpots.TrackpyLocalMaxPeakFinder(
    spot_diameter=1,  # must be odd integer
    min_mass=0.01,
    max_size=4,  # this is max radius
    separation=1,
    noise_size=0.65,  # this is not used because preprocess is False
    preprocess=False,
    percentile=10,  # this is irrelevant when min_mass, spot_diameter, and max_size are set properly
    verbose=True,
    is_volume=True,
)
lmpf = starfish.spots.DetectSpots.LocalMaxPeakFinder(
min_distance=1,
stringency=0,
min_obj_area=1,
max_obj_area=20,
verbose=True,
is_volume=True)

#intensities = lsbd.run(z_proj, n_processes=22)
intensities = tlmpf.run(clipper.run(image), n_processes=22)
# intensities = lmpf.run(clipper.run(image), n_processes=22)
# Out:
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/trackpy/masks.py:20: RuntimeWarning: invalid value encountered in true_divide
#   r = [(coord/rad)**2 for (coord, rad) in zip(coords, radius)]
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/trackpy/masks.py:38: RuntimeWarning: invalid value encountered in true_divide
#   r = [(coord/rad)**2 for (coord, rad) in zip(coords, radius)]
# /home/nomi/Desktop/starfish/.venv/lib/python3.7/site-packages/trackpy/refine/center_of_mass.py:261: RuntimeWarning: invalid value encountered in true_divide
#   neighborhood) / mass[feat])

# %% [markdown]
# Decode spots
# ------------
# Next, spots are decoded.

# %%
decoded = experiment.codebook.decode_per_round_max(intensities.fillna(0))
decode_mask = decoded['target'] != 'nan'

# %%
import sklearn
print(sorted(sklearn.neighbors.VALID_METRICS['ball_tree']))
decoded = experiment.codebook.decode_metric(intensities.fillna(0), 1, 0, 2, 'l2')
decode_mask = decoded['target'] != 'nan'
# Out:
# ['braycurtis', 'canberra', 'chebyshev', 'cityblock', 'dice', 'euclidean', 'hamming', 'haversine', 'infinity', 'jaccard', 'kulsinski', 'l1', 'l2', 'mahalanobis', 'manhattan', 'matching', 'minkowski', 'p', 'pyfunc', 'rogerstanimoto', 'russellrao', 'seuclidean', 'sokalmichener', 'sokalsneath', 'wminkowski']

# %%
import pandas as pd
from starfish.types import Features
from starfish.core.types import DecodedSpots

df = pd.DataFrame(dict(decoded['features'].coords))
pixel_coordinates = pd.Index(['x', 'y', 'z'])
ds = DecodedSpots(df)

# %%
ds.data
# Out:
#      eccentricity  ep    radius  raw_mass  total_intensity           x  \
# 0             NaN NaN  0.886510  0.026368         0.026265  426.961706
# 1             NaN NaN  0.899626  0.022141         0.022059  696.981347
# 2             NaN NaN  0.885517  0.020829         0.020756  438.975771
# 3             NaN NaN  0.893492  0.021927         0.021876  452.054336
# 4             NaN NaN  0.905902  0.020233         0.020138  454.996595
# 5             NaN NaN  0.912871  0.022019         0.021944  431.027083
# 6             NaN NaN  0.917632  0.021500         0.021419  432.987193
# 7             NaN NaN  0.908054  0.020951         0.020847  433.964912
# 8             NaN NaN  0.894427  0.029236         0.029145  439.982745
# 9             NaN NaN  0.896778  0.021820         0.021716  626.960000
# 10            NaN NaN  0.900340  0.025071         0.024984  729.039341
# 11            NaN NaN  0.912354  0.020249         0.020184  729.988675
# 12            NaN NaN  0.909437  0.020157         0.020093  731.000000
# 13            NaN NaN  0.911135  0.020523         0.020458  731.017877
# 14            NaN NaN  0.907226  0.020096         0.020024  737.981735
# 15            NaN NaN  0.907416  0.021546         0.021487  733.007447
# 16            NaN NaN  0.902824  0.021592         0.021510  741.022317
# 17            NaN NaN  0.909802  0.020508         0.020436  716.006711
# 18            NaN NaN  0.905162  0.020218         0.020116  704.018182
# 19            NaN NaN  0.895558  0.020417         0.020321  174.979753
# 20            NaN NaN  0.895314  0.023117         0.023041  454.008929
# 21            NaN NaN  0.910188  0.020325         0.020253  452.985327
# 22            NaN NaN  0.918464  0.020569         0.020458  453.993296
# 23            NaN NaN  0.888622  0.027451         0.027385  464.006678
# 24            NaN NaN  0.901900  0.020172         0.020093  423.025028
# 25            NaN NaN  0.907515  0.025101         0.025007  453.985375
# 26            NaN NaN  0.908281  0.022416         0.022333  454.955988
# 27            NaN NaN  0.900077  0.024887         0.024802  455.037788
# 28            NaN NaN  0.896520  0.020783         0.020733  467.026461
# 29            NaN NaN  0.897060  0.024323         0.024230  458.967925
# ..            ...  ..       ...       ...              ...         ...
# 113           NaN NaN  0.929854  0.021042         0.020938  426.051310
# 114           NaN NaN  0.908745  0.025925         0.025853  427.996463
# 115           NaN NaN  0.921149  0.023148         0.023087  430.000000
# 116           NaN NaN  0.910349  0.024063         0.024024  439.019029
# 117           NaN NaN  0.925904  0.021057         0.020984  440.978214
# 118           NaN NaN  0.908326  0.020340         0.020253  418.047404
# 119           NaN NaN  0.924670  0.023072         0.023019  429.997021
# 120           NaN NaN  0.917535  0.020584         0.020527  438.031180
# 121           NaN NaN  0.929772  0.022339         0.022264  428.982546
# 122           NaN NaN  0.920379  0.020554         0.020481  440.017857
# 123           NaN NaN  0.914619  0.022721         0.022653  426.990918
# 124           NaN NaN  0.894816  0.026383         0.026265  426.991297
# 125           NaN NaN  0.908622  0.020264         0.020184  428.928652
# 126           NaN NaN  0.902901  0.020508         0.020413  591.005599
# 127           NaN NaN  0.899355  0.020768         0.020687  603.034254
# 128           NaN NaN  0.916810  0.025483         0.025373  458.969369
# 129           NaN NaN  0.900980  0.025330         0.025259  458.048869
# 130           NaN NaN  0.906896  0.021454         0.021373  435.954011
# 131           NaN NaN  0.899782  0.025757         0.025693  451.979537
# 132           NaN NaN  0.891669  0.020478         0.020413  421.983203
# 133           NaN NaN  0.907814  0.020340         0.020276  426.959414
# 134           NaN NaN  0.897570  0.025223         0.025167  422.060854
# 135           NaN NaN  0.911825  0.022065         0.021967  425.971904
# 136           NaN NaN  0.916891  0.021302         0.021236  425.023681
# 137           NaN NaN  0.895405  0.023621         0.023522  433.983479
# 138           NaN NaN  0.892866  0.024659         0.024573  441.061395
# 139           NaN NaN  0.911125  0.021622         0.021533  425.955414
# 140           NaN NaN  0.901769  0.020890         0.020801  432.926374
# 141           NaN NaN  0.898183  0.021134         0.021053  451.051031
# 142           NaN NaN  0.900757  0.020218         0.020116  433.028409
#
#                y         z  features        xc        yc       zc target  \
# 0     954.013925  2.006092         0  0.000053  0.000024  0.00005    RFP
# 1    2980.972021  2.008290         1  0.000087  0.000075  0.00005    RFP
# 2    3469.027533  2.001101         2  0.000055  0.000087  0.00005    RFP
# 3    3469.045977  2.008359         3  0.000057  0.000087  0.00005    RFP
# 4    3472.997730  2.020431         4  0.000057  0.000087  0.00005    RFP
# 5    3724.008333  2.052083         5  0.000054  0.000093  0.00005    RFP
# 6    3724.010672  2.033084         6  0.000054  0.000093  0.00005    RFP
# 7    3724.994518  2.029605         7  0.000054  0.000093  0.00005    RFP
# 8    3726.040000  2.058824         8  0.000055  0.000093  0.00005    RFP
# 9    2546.004211  2.997895         9  0.000078  0.000064  0.00005    RFP
# 10   2901.983532  3.000915        10  0.000091  0.000073  0.00005    RFP
# 11   2909.003398  2.997735        11  0.000091  0.000073  0.00005    RFP
# 12   2910.006826  2.994312        12  0.000091  0.000073  0.00005    RFP
# 13   2911.015642  2.994413        13  0.000091  0.000073  0.00005    RFP
# 14   2940.981735  3.001142        14  0.000092  0.000074  0.00005    RFP
# 15   2943.997872  2.986170        15  0.000092  0.000074  0.00005    RFP
# 16   2944.982997  2.995749        16  0.000093  0.000074  0.00005    RFP
# 17   2983.015660  2.986577        17  0.000090  0.000075  0.00005    RFP
# 18   2984.006818  2.992045        18  0.000088  0.000075  0.00005    RFP
# 19   3103.971879  3.006749        19  0.000022  0.000078  0.00005    RFP
# 20   3457.004960  3.001984        20  0.000057  0.000086  0.00005    RFP
# 21   3462.021445  3.024831        21  0.000057  0.000087  0.00005    RFP
# 22   3465.041341  3.008939        22  0.000057  0.000087  0.00005    RFP
# 23   3468.919032  3.002504        23  0.000058  0.000087  0.00005    RFP
# 24   3470.007964  3.000000        24  0.000053  0.000087  0.00005    RFP
# 25   3476.979890  3.008227        25  0.000057  0.000087  0.00005    RFP
# 26   3477.987718  3.021494        26  0.000057  0.000087  0.00005    RFP
# 27   3480.031336  3.040553        27  0.000057  0.000087  0.00005    RFP
# 28   3481.975744  3.023153        28  0.000058  0.000087  0.00005    RFP
# 29   3483.996226  2.997170        29  0.000057  0.000087  0.00005    RFP
# ..           ...       ...       ...       ...       ...      ...    ...
# 113  3751.013100  3.092795       113  0.000053  0.000094  0.00005    RFP
# 114  3750.991158  3.063660       114  0.000054  0.000094  0.00005    RFP
# 115  3750.990099  3.032673       115  0.000054  0.000094  0.00005    RFP
# 116  3750.949572  2.990485       116  0.000055  0.000094  0.00005    RFP
# 117  3751.020697  2.993464       117  0.000055  0.000094  0.00005    RFP
# 118  3751.965011  3.002257       118  0.000052  0.000094  0.00005    RFP
# 119  3751.994042  3.051639       119  0.000054  0.000094  0.00005    RFP
# 120  3751.973274  2.997773       120  0.000055  0.000094  0.00005    RFP
# 121  3752.969199  3.052361       121  0.000054  0.000094  0.00005    RFP
# 122  3752.959821  2.987723       122  0.000055  0.000094  0.00005    RFP
# 123  3754.048436  3.008073       123  0.000053  0.000094  0.00005    RFP
# 124  3755.965187  3.006963       124  0.000053  0.000094  0.00005    RFP
# 125  3756.000000  3.006795       125  0.000054  0.000094  0.00005    RFP
# 126  3131.002240  4.005599       126  0.000074  0.000078  0.00005    RFP
# 127  3156.014365  4.002210       127  0.000075  0.000079  0.00005    RFP
# 128  3467.045946  3.989189       128  0.000057  0.000087  0.00005    RFP
# 129  3467.952941  4.020814       129  0.000057  0.000087  0.00005    RFP
# 130  3482.020321  4.007487       130  0.000055  0.000087  0.00005    RFP
# 131  3487.938612  3.944840       131  0.000057  0.000087  0.00005    RFP
# 132  3687.977604  3.996641       132  0.000053  0.000092  0.00005    RFP
# 133  3698.003382  4.045096       133  0.000053  0.000092  0.00005    RFP
# 134  3698.996367  3.983651       134  0.000053  0.000092  0.00005    RFP
# 135  3718.978148  3.986472       135  0.000053  0.000093  0.00005    RFP
# 136  3719.976319  3.970936       136  0.000053  0.000093  0.00005    RFP
# 137  3736.991254  3.971817       137  0.000054  0.000093  0.00005    RFP
# 138  3736.940465  3.954419       138  0.000055  0.000093  0.00005    RFP
# 139  3750.040340  3.944798       139  0.000053  0.000094  0.00005    RFP
# 140  3756.981319  3.995604       140  0.000054  0.000094  0.00005    RFP
# 141  3460.980456  4.963084       141  0.000056  0.000087  0.00005    RFP
# 142  3680.000000  5.007955       142  0.000054  0.000092  0.00005    RFP
#
#      distance  passes_thresholds
# 0         0.0               True
# 1         0.0               True
# 2         0.0               True
# 3         0.0               True
# 4         0.0               True
# 5         0.0               True
# 6         0.0               True
# 7         0.0               True
# 8         0.0               True
# 9         0.0               True
# 10        0.0               True
# 11        0.0               True
# 12        0.0               True
# 13        0.0               True
# 14        0.0               True
# 15        0.0               True
# 16        0.0               True
# 17        0.0               True
# 18        0.0               True
# 19        0.0               True
# 20        0.0               True
# 21        0.0               True
# 22        0.0               True
# 23        0.0               True
# 24        0.0               True
# 25        0.0               True
# 26        0.0               True
# 27        0.0               True
# 28        0.0               True
# 29        0.0               True
# ..        ...                ...
# 113       0.0               True
# 114       0.0               True
# 115       0.0               True
# 116       0.0               True
# 117       0.0               True
# 118       0.0               True
# 119       0.0               True
# 120       0.0               True
# 121       0.0               True
# 122       0.0               True
# 123       0.0               True
# 124       0.0               True
# 125       0.0               True
# 126       0.0               True
# 127       0.0               True
# 128       0.0               True
# 129       0.0               True
# 130       0.0               True
# 131       0.0               True
# 132       0.0               True
# 133       0.0               True
# 134       0.0               True
# 135       0.0               True
# 136       0.0               True
# 137       0.0               True
# 138       0.0               True
# 139       0.0               True
# 140       0.0               True
# 141       0.0               True
# 142       0.0               True
#
# [143 rows x 15 columns]

# %%
# %gui qt
viewer = starfish.display(
    z_proj, decoded[decode_mask], radius_multiplier=10, mask_intensities=0.00
)

# %%
ds.data.loc[1]
# Out:
# radius                         2
# x                             11
# x_max                         13
# x_min                         10
# y                           3987
# y_max                       3989
# y_min                       3986
# z                              0
# z_max                          1
# z_min                          0
# features                       1
# xc                   1.37672e-06
# yc                   9.96999e-05
# zc                         5e-05
# target                       GFP
# distance                       0
# passes_thresholds           True
# Name: 1, dtype: object

# %%
for i,j in ds.data.iterrows():
    if j['target'] == 'RFP':
        print(j)
# Out:
# radius                         1
# x                            612
# x_max                        613
# x_min                        612
# y                           3960
# y_max                       3961
# y_min                       3960
# z                              0
# z_max                          1
# z_min                          0
# features                    4207
# xc                   7.65957e-05
# yc                   9.90248e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4207, dtype: object
# radius                         1
# x                            601
# x_max                        602
# x_min                        601
# y                           3956
# y_max                       3957
# y_min                       3956
# z                              0
# z_max                          1
# z_min                          0
# features                    4208
# xc                    7.5219e-05
# yc                   9.89247e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4208, dtype: object
# radius                         1
# x                            432
# x_max                        433
# x_min                        432
# y                           3757
# y_max                       3758
# y_min                       3757
# z                              0
# z_max                          1
# z_min                          0
# features                    4209
# xc                   5.40676e-05
# yc                   9.39485e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4209, dtype: object
# radius                         1
# x                            420
# x_max                        421
# x_min                        420
# y                           3757
# y_max                       3758
# y_min                       3757
# z                              0
# z_max                          1
# z_min                          0
# features                    4210
# xc                   5.25657e-05
# yc                   9.39485e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4210, dtype: object
# radius                         1
# x                            427
# x_max                        428
# x_min                        427
# y                           3756
# y_max                       3757
# y_min                       3756
# z                              0
# z_max                          1
# z_min                          0
# features                    4211
# xc                   5.34418e-05
# yc                   9.39235e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4211, dtype: object
# radius                         1
# x                            436
# x_max                        437
# x_min                        436
# y                           3754
# y_max                       3755
# y_min                       3754
# z                              0
# z_max                          1
# z_min                          0
# features                    4212
# xc                   5.45682e-05
# yc                   9.38735e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4212, dtype: object
# radius                         1
# x                            440
# x_max                        441
# x_min                        440
# y                           3752
# y_max                       3753
# y_min                       3752
# z                              0
# z_max                          1
# z_min                          0
# features                    4213
# xc                   5.50688e-05
# yc                   9.38235e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4213, dtype: object
# radius                         1
# x                            427
# x_max                        428
# x_min                        427
# y                           3752
# y_max                       3753
# y_min                       3752
# z                              0
# z_max                          1
# z_min                          0
# features                    4214
# xc                   5.34418e-05
# yc                   9.38235e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4214, dtype: object
# radius                         1
# x                            419
# x_max                        420
# x_min                        419
# y                           3752
# y_max                       3753
# y_min                       3752
# z                              0
# z_max                          1
# z_min                          0
# features                    4215
# xc                   5.24406e-05
# yc                   9.38235e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4215, dtype: object
# radius                         1
# x                            405
# x_max                        406
# x_min                        405
# y                           3752
# y_max                       3753
# y_min                       3752
# z                              0
# z_max                          1
# z_min                          0
# features                    4216
# xc                   5.06884e-05
# yc                   9.38235e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4216, dtype: object
# radius                         1
# x                            442
# x_max                        443
# x_min                        442
# y                           3751
# y_max                       3752
# y_min                       3751
# z                              0
# z_max                          1
# z_min                          0
# features                    4217
# xc                   5.53191e-05
# yc                   9.37984e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4217, dtype: object
# radius                         1
# x                            431
# x_max                        432
# x_min                        431
# y                           3751
# y_max                       3752
# y_min                       3751
# z                              0
# z_max                          1
# z_min                          0
# features                    4218
# xc                   5.39424e-05
# yc                   9.37984e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4218, dtype: object
# radius                         1
# x                            439
# x_max                        440
# x_min                        439
# y                           3750
# y_max                       3751
# y_min                       3750
# z                              0
# z_max                          1
# z_min                          0
# features                    4219
# xc                   5.49437e-05
# yc                   9.37734e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4219, dtype: object
# radius                         1
# x                            435
# x_max                        436
# x_min                        435
# y                           3750
# y_max                       3751
# y_min                       3750
# z                              0
# z_max                          1
# z_min                          0
# features                    4220
# xc                   5.44431e-05
# yc                   9.37734e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4220, dtype: object
# radius                         1
# x                            425
# x_max                        426
# x_min                        425
# y                           3750
# y_max                       3751
# y_min                       3750
# z                              0
# z_max                          1
# z_min                          0
# features                    4221
# xc                   5.31915e-05
# yc                   9.37734e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4221, dtype: object
# radius                         1
# x                            430
# x_max                        431
# x_min                        430
# y                           3749
# y_max                       3750
# y_min                       3749
# z                              0
# z_max                          1
# z_min                          0
# features                    4222
# xc                   5.38173e-05
# yc                   9.37484e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4222, dtype: object
# radius                         1
# x                            413
# x_max                        414
# x_min                        413
# y                           3749
# y_max                       3750
# y_min                       3749
# z                              0
# z_max                          1
# z_min                          0
# features                    4223
# xc                   5.16896e-05
# yc                   9.37484e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4223, dtype: object
# radius                         1
# x                            424
# x_max                        425
# x_min                        424
# y                           3747
# y_max                       3748
# y_min                       3747
# z                              0
# z_max                          1
# z_min                          0
# features                    4224
# xc                   5.30663e-05
# yc                   9.36984e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4224, dtype: object
# radius                         1
# x                            421
# x_max                        422
# x_min                        421
# y                           3747
# y_max                       3748
# y_min                       3747
# z                              0
# z_max                          1
# z_min                          0
# features                    4225
# xc                   5.26909e-05
# yc                   9.36984e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4225, dtype: object
# radius                         1
# x                            417
# x_max                        418
# x_min                        417
# y                           3747
# y_max                       3748
# y_min                       3747
# z                              0
# z_max                          1
# z_min                          0
# features                    4226
# xc                   5.21902e-05
# yc                   9.36984e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4226, dtype: object
# radius                         1
# x                            427
# x_max                        428
# x_min                        427
# y                           3746
# y_max                       3747
# y_min                       3746
# z                              0
# z_max                          1
# z_min                          0
# features                    4227
# xc                   5.34418e-05
# yc                   9.36734e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4227, dtype: object
# radius                         1
# x                            424
# x_max                        425
# x_min                        424
# y                           3745
# y_max                       3746
# y_min                       3745
# z                              0
# z_max                          1
# z_min                          0
# features                    4228
# xc                   5.30663e-05
# yc                   9.36484e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4228, dtype: object
# radius                         1
# x                            440
# x_max                        441
# x_min                        440
# y                           3744
# y_max                       3745
# y_min                       3744
# z                              0
# z_max                          1
# z_min                          0
# features                    4229
# xc                   5.50688e-05
# yc                   9.36234e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4229, dtype: object
# radius                         1
# x                            419
# x_max                        420
# x_min                        419
# y                           3744
# y_max                       3745
# y_min                       3744
# z                              0
# z_max                          1
# z_min                          0
# features                    4230
# xc                   5.24406e-05
# yc                   9.36234e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4230, dtype: object
# radius                         1
# x                            437
# x_max                        438
# x_min                        437
# y                           3741
# y_max                       3742
# y_min                       3741
# z                              0
# z_max                          1
# z_min                          0
# features                    4231
# xc                   5.46934e-05
# yc                   9.35484e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4231, dtype: object
# radius                         1
# x                            431
# x_max                        432
# x_min                        431
# y                           3741
# y_max                       3742
# y_min                       3741
# z                              0
# z_max                          1
# z_min                          0
# features                    4232
# xc                   5.39424e-05
# yc                   9.35484e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4232, dtype: object
# radius                         1
# x                            418
# x_max                        419
# x_min                        418
# y                           3741
# y_max                       3742
# y_min                       3741
# z                              0
# z_max                          1
# z_min                          0
# features                    4233
# xc                   5.23154e-05
# yc                   9.35484e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4233, dtype: object
# radius                         1
# x                            445
# x_max                        446
# x_min                        445
# y                           3740
# y_max                       3741
# y_min                       3740
# z                              0
# z_max                          1
# z_min                          0
# features                    4234
# xc                   5.56946e-05
# yc                   9.35234e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4234, dtype: object
# radius                         1
# x                            443
# x_max                        444
# x_min                        443
# y                           3740
# y_max                       3741
# y_min                       3740
# z                              0
# z_max                          1
# z_min                          0
# features                    4235
# xc                   5.54443e-05
# yc                   9.35234e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4235, dtype: object
# radius                         1
# x                            422
# x_max                        423
# x_min                        422
# y                           3740
# y_max                       3741
# y_min                       3740
# z                              0
# z_max                          1
# z_min                          0
# features                    4236
# xc                    5.2816e-05
# yc                   9.35234e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4236, dtype: object
# radius                         1
# x                            411
# x_max                        412
# x_min                        411
# y                           3740
# y_max                       3741
# y_min                       3740
# z                              0
# z_max                          1
# z_min                          0
# features                    4237
# xc                   5.14393e-05
# yc                   9.35234e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4237, dtype: object
# radius                         1
# x                            437
# x_max                        438
# x_min                        437
# y                           3739
# y_max                       3740
# y_min                       3739
# z                              0
# z_max                          1
# z_min                          0
# features                    4238
# xc                   5.46934e-05
# yc                   9.34984e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4238, dtype: object
# radius                         1
# x                            417
# x_max                        418
# x_min                        417
# y                           3739
# y_max                       3740
# y_min                       3739
# z                              0
# z_max                          1
# z_min                          0
# features                    4239
# xc                   5.21902e-05
# yc                   9.34984e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4239, dtype: object
# radius                         1
# x                            446
# x_max                        447
# x_min                        446
# y                           3737
# y_max                       3738
# y_min                       3737
# z                              0
# z_max                          1
# z_min                          0
# features                    4240
# xc                   5.58198e-05
# yc                   9.34484e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4240, dtype: object
# radius                         1
# x                            441
# x_max                        442
# x_min                        441
# y                           3737
# y_max                       3738
# y_min                       3737
# z                              0
# z_max                          1
# z_min                          0
# features                    4241
# xc                    5.5194e-05
# yc                   9.34484e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4241, dtype: object
# radius                         1
# x                            434
# x_max                        435
# x_min                        434
# y                           3737
# y_max                       3738
# y_min                       3737
# z                              0
# z_max                          1
# z_min                          0
# features                    4242
# xc                   5.43179e-05
# yc                   9.34484e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4242, dtype: object
# radius                         1
# x                            439
# x_max                        440
# x_min                        439
# y                           3736
# y_max                       3737
# y_min                       3736
# z                              0
# z_max                          1
# z_min                          0
# features                    4243
# xc                   5.49437e-05
# yc                   9.34234e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4243, dtype: object
# radius                         1
# x                            432
# x_max                        433
# x_min                        432
# y                           3736
# y_max                       3737
# y_min                       3736
# z                              0
# z_max                          1
# z_min                          0
# features                    4244
# xc                   5.40676e-05
# yc                   9.34234e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4244, dtype: object
# radius                         1
# x                            428
# x_max                        429
# x_min                        428
# y                           3736
# y_max                       3737
# y_min                       3736
# z                              0
# z_max                          1
# z_min                          0
# features                    4245
# xc                    5.3567e-05
# yc                   9.34234e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4245, dtype: object
# radius                         1
# x                            426
# x_max                        427
# x_min                        426
# y                           3735
# y_max                       3736
# y_min                       3735
# z                              0
# z_max                          1
# z_min                          0
# features                    4246
# xc                   5.33166e-05
# yc                   9.33983e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4246, dtype: object
# radius                         1
# x                            436
# x_max                        437
# x_min                        436
# y                           3732
# y_max                       3733
# y_min                       3732
# z                              0
# z_max                          1
# z_min                          0
# features                    4247
# xc                   5.45682e-05
# yc                   9.33233e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4247, dtype: object
# radius                         1
# x                            431
# x_max                        432
# x_min                        431
# y                           3732
# y_max                       3733
# y_min                       3732
# z                              0
# z_max                          1
# z_min                          0
# features                    4248
# xc                   5.39424e-05
# yc                   9.33233e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4248, dtype: object
# radius                         1
# x                            426
# x_max                        427
# x_min                        426
# y                           3732
# y_max                       3733
# y_min                       3732
# z                              0
# z_max                          1
# z_min                          0
# features                    4249
# xc                   5.33166e-05
# yc                   9.33233e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4249, dtype: object
# radius                         1
# x                            443
# x_max                        444
# x_min                        443
# y                           3730
# y_max                       3731
# y_min                       3730
# z                              0
# z_max                          1
# z_min                          0
# features                    4250
# xc                   5.54443e-05
# yc                   9.32733e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4250, dtype: object
# radius                         1
# x                            439
# x_max                        440
# x_min                        439
# y                           3730
# y_max                       3731
# y_min                       3730
# z                              0
# z_max                          1
# z_min                          0
# features                    4251
# xc                   5.49437e-05
# yc                   9.32733e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4251, dtype: object
# radius                         1
# x                            437
# x_max                        438
# x_min                        437
# y                           3730
# y_max                       3731
# y_min                       3730
# z                              0
# z_max                          1
# z_min                          0
# features                    4252
# xc                   5.46934e-05
# yc                   9.32733e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4252, dtype: object
# radius                         1
# x                            429
# x_max                        430
# x_min                        429
# y                           3729
# y_max                       3730
# y_min                       3729
# z                              0
# z_max                          1
# z_min                          0
# features                    4253
# xc                   5.36921e-05
# yc                   9.32483e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4253, dtype: object
# radius                         1
# x                            446
# x_max                        447
# x_min                        446
# y                           3728
# y_max                       3729
# y_min                       3728
# z                              0
# z_max                          1
# z_min                          0
# features                    4254
# xc                   5.58198e-05
# yc                   9.32233e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4254, dtype: object
# radius                         1
# x                            446
# x_max                        447
# x_min                        446
# y                           3726
# y_max                       3727
# y_min                       3726
# z                              0
# z_max                          1
# z_min                          0
# features                    4255
# xc                   5.58198e-05
# yc                   9.31733e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4255, dtype: object
# radius                         1
# x                            440
# x_max                        441
# x_min                        440
# y                           3726
# y_max                       3727
# y_min                       3726
# z                              0
# z_max                          1
# z_min                          0
# features                    4256
# xc                   5.50688e-05
# yc                   9.31733e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4256, dtype: object
# radius                         1
# x                            427
# x_max                        428
# x_min                        427
# y                           3726
# y_max                       3727
# y_min                       3726
# z                              0
# z_max                          1
# z_min                          0
# features                    4257
# xc                   5.34418e-05
# yc                   9.31733e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4257, dtype: object
# radius                         1
# x                            434
# x_max                        435
# x_min                        434
# y                           3725
# y_max                       3726
# y_min                       3725
# z                              0
# z_max                          1
# z_min                          0
# features                    4258
# xc                   5.43179e-05
# yc                   9.31483e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4258, dtype: object
# radius                         1
# x                            423
# x_max                        424
# x_min                        423
# y                           3725
# y_max                       3726
# y_min                       3725
# z                              0
# z_max                          1
# z_min                          0
# features                    4259
# xc                   5.29412e-05
# yc                   9.31483e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4259, dtype: object
# radius                         1
# x                            436
# x_max                        437
# x_min                        436
# y                           3724
# y_max                       3725
# y_min                       3724
# z                              0
# z_max                          1
# z_min                          0
# features                    4260
# xc                   5.45682e-05
# yc                   9.31233e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4260, dtype: object
# radius                         1
# x                            432
# x_max                        433
# x_min                        432
# y                           3724
# y_max                       3725
# y_min                       3724
# z                              0
# z_max                          1
# z_min                          0
# features                    4261
# xc                   5.40676e-05
# yc                   9.31233e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4261, dtype: object
# radius                         1
# x                            426
# x_max                        427
# x_min                        426
# y                           3724
# y_max                       3725
# y_min                       3724
# z                              0
# z_max                          1
# z_min                          0
# features                    4262
# xc                   5.33166e-05
# yc                   9.31233e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4262, dtype: object
# radius                         1
# x                            449
# x_max                        450
# x_min                        449
# y                           3723
# y_max                       3724
# y_min                       3723
# z                              0
# z_max                          1
# z_min                          0
# features                    4263
# xc                   5.61952e-05
# yc                   9.30983e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4263, dtype: object
# radius                         1
# x                            446
# x_max                        447
# x_min                        446
# y                           3723
# y_max                       3724
# y_min                       3723
# z                              0
# z_max                          1
# z_min                          0
# features                    4264
# xc                   5.58198e-05
# yc                   9.30983e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4264, dtype: object
# radius                         1
# x                            434
# x_max                        435
# x_min                        434
# y                           3723
# y_max                       3724
# y_min                       3723
# z                              0
# z_max                          1
# z_min                          0
# features                    4265
# xc                   5.43179e-05
# yc                   9.30983e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4265, dtype: object
# radius                         1
# x                            414
# x_max                        415
# x_min                        414
# y                           3722
# y_max                       3723
# y_min                       3722
# z                              0
# z_max                          1
# z_min                          0
# features                    4266
# xc                   5.18148e-05
# yc                   9.30733e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4266, dtype: object
# radius                         1
# x                            446
# x_max                        447
# x_min                        446
# y                           3721
# y_max                       3722
# y_min                       3721
# z                              0
# z_max                          1
# z_min                          0
# features                    4267
# xc                   5.58198e-05
# yc                   9.30483e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4267, dtype: object
# radius                         1
# x                            425
# x_max                        426
# x_min                        425
# y                           3719
# y_max                       3720
# y_min                       3719
# z                              0
# z_max                          1
# z_min                          0
# features                    4268
# xc                   5.31915e-05
# yc                   9.29982e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4268, dtype: object
# radius                         1
# x                            454
# x_max                        455
# x_min                        454
# y                           3718
# y_max                       3719
# y_min                       3718
# z                              0
# z_max                          1
# z_min                          0
# features                    4269
# xc                    5.6821e-05
# yc                   9.29732e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4269, dtype: object
# radius                         1
# x                            413
# x_max                        414
# x_min                        413
# y                           3715
# y_max                       3716
# y_min                       3715
# z                              0
# z_max                          1
# z_min                          0
# features                    4270
# xc                   5.16896e-05
# yc                   9.28982e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4270, dtype: object
# radius                         1
# x                            457
# x_max                        458
# x_min                        457
# y                           3712
# y_max                       3713
# y_min                       3712
# z                              0
# z_max                          1
# z_min                          0
# features                    4271
# xc                   5.71965e-05
# yc                   9.28232e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4271, dtype: object
# radius                         1
# x                            416
# x_max                        417
# x_min                        416
# y                           3707
# y_max                       3708
# y_min                       3707
# z                              0
# z_max                          1
# z_min                          0
# features                    4272
# xc                   5.20651e-05
# yc                   9.26982e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4272, dtype: object
# radius                         1
# x                            421
# x_max                        422
# x_min                        421
# y                           3705
# y_max                       3706
# y_min                       3705
# z                              0
# z_max                          1
# z_min                          0
# features                    4273
# xc                   5.26909e-05
# yc                   9.26482e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4273, dtype: object
# radius                         1
# x                            417
# x_max                        418
# x_min                        417
# y                           3705
# y_max                       3706
# y_min                       3705
# z                              0
# z_max                          1
# z_min                          0
# features                    4274
# xc                   5.21902e-05
# yc                   9.26482e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4274, dtype: object
# radius                         1
# x                            445
# x_max                        446
# x_min                        445
# y                           3704
# y_max                       3705
# y_min                       3704
# z                              0
# z_max                          1
# z_min                          0
# features                    4275
# xc                   5.56946e-05
# yc                   9.26232e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4275, dtype: object
# radius                         1
# x                            455
# x_max                        456
# x_min                        455
# y                           3703
# y_max                       3704
# y_min                       3703
# z                              0
# z_max                          1
# z_min                          0
# features                    4276
# xc                   5.69462e-05
# yc                   9.25981e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4276, dtype: object
# radius                         1
# x                            444
# x_max                        445
# x_min                        444
# y                           3700
# y_max                       3701
# y_min                       3700
# z                              0
# z_max                          1
# z_min                          0
# features                    4277
# xc                   5.55695e-05
# yc                   9.25231e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4277, dtype: object
# radius                         1
# x                            422
# x_max                        423
# x_min                        422
# y                           3699
# y_max                       3700
# y_min                       3699
# z                              0
# z_max                          1
# z_min                          0
# features                    4278
# xc                    5.2816e-05
# yc                   9.24981e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4278, dtype: object
# radius                         1
# x                            427
# x_max                        428
# x_min                        427
# y                           3698
# y_max                       3699
# y_min                       3698
# z                              0
# z_max                          1
# z_min                          0
# features                    4279
# xc                   5.34418e-05
# yc                   9.24731e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4279, dtype: object
# radius                         1
# x                            419
# x_max                        420
# x_min                        419
# y                           3697
# y_max                       3698
# y_min                       3697
# z                              0
# z_max                          1
# z_min                          0
# features                    4280
# xc                   5.24406e-05
# yc                   9.24481e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4280, dtype: object
# radius                         1
# x                            430
# x_max                        431
# x_min                        430
# y                           3691
# y_max                       3692
# y_min                       3691
# z                              0
# z_max                          1
# z_min                          0
# features                    4281
# xc                   5.38173e-05
# yc                   9.22981e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4281, dtype: object
# radius                         1
# x                            428
# x_max                        429
# x_min                        428
# y                           3690
# y_max                       3691
# y_min                       3690
# z                              0
# z_max                          1
# z_min                          0
# features                    4282
# xc                    5.3567e-05
# yc                   9.22731e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4282, dtype: object
# radius                         1
# x                            426
# x_max                        427
# x_min                        426
# y                           3689
# y_max                       3690
# y_min                       3689
# z                              0
# z_max                          1
# z_min                          0
# features                    4283
# xc                   5.33166e-05
# yc                   9.22481e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4283, dtype: object
# radius                         1
# x                            422
# x_max                        423
# x_min                        422
# y                           3688
# y_max                       3689
# y_min                       3688
# z                              0
# z_max                          1
# z_min                          0
# features                    4284
# xc                    5.2816e-05
# yc                   9.22231e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4284, dtype: object
# radius                         1
# x                            455
# x_max                        456
# x_min                        455
# y                           3686
# y_max                       3687
# y_min                       3686
# z                              0
# z_max                          1
# z_min                          0
# features                    4285
# xc                   5.69462e-05
# yc                    9.2173e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4285, dtype: object
# radius                         1
# x                            423
# x_max                        424
# x_min                        423
# y                           3685
# y_max                       3686
# y_min                       3685
# z                              0
# z_max                          1
# z_min                          0
# features                    4286
# xc                   5.29412e-05
# yc                    9.2148e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4286, dtype: object
# radius                         1
# x                            433
# x_max                        434
# x_min                        433
# y                           3683
# y_max                       3684
# y_min                       3683
# z                              0
# z_max                          1
# z_min                          0
# features                    4287
# xc                   5.41927e-05
# yc                    9.2098e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4287, dtype: object
# radius                         1
# x                            445
# x_max                        446
# x_min                        445
# y                           3680
# y_max                       3681
# y_min                       3680
# z                              0
# z_max                          1
# z_min                          0
# features                    4288
# xc                   5.56946e-05
# yc                    9.2023e-05
# ...
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4338, dtype: object
# radius                         1
# x                            741
# x_max                        742
# x_min                        741
# y                           2945
# y_max                       2946
# y_min                       2945
# z                              0
# z_max                          1
# z_min                          0
# features                    4339
# xc                   9.27409e-05
# yc                   7.36434e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4339, dtype: object
# radius                         1
# x                            733
# x_max                        734
# x_min                        733
# y                           2944
# y_max                       2945
# y_min                       2944
# z                              0
# z_max                          1
# z_min                          0
# features                    4340
# xc                   9.17397e-05
# yc                   7.36184e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4340, dtype: object
# radius                         1
# x                            738
# x_max                        739
# x_min                        738
# y                           2940
# y_max                       2941
# y_min                       2940
# z                              0
# z_max                          1
# z_min                          0
# features                    4341
# xc                   9.23655e-05
# yc                   7.35184e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4341, dtype: object
# radius                         1
# x                            738
# x_max                        739
# x_min                        738
# y                           2928
# y_max                       2929
# y_min                       2928
# z                              0
# z_max                          1
# z_min                          0
# features                    4342
# xc                   9.23655e-05
# yc                   7.32183e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4342, dtype: object
# radius                         1
# x                            731
# x_max                        732
# x_min                        731
# y                           2912
# y_max                       2913
# y_min                       2912
# z                              0
# z_max                          1
# z_min                          0
# features                    4343
# xc                   9.14894e-05
# yc                   7.28182e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4343, dtype: object
# radius                         1
# x                            729
# x_max                        730
# x_min                        729
# y                           2908
# y_max                       2909
# y_min                       2908
# z                              0
# z_max                          1
# z_min                          0
# features                    4344
# xc                    9.1239e-05
# yc                   7.27182e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4344, dtype: object
# radius                         1
# x                            315
# x_max                        316
# x_min                        315
# y                           2908
# y_max                       2909
# y_min                       2908
# z                              0
# z_max                          1
# z_min                          0
# features                    4345
# xc                   3.94243e-05
# yc                   7.27182e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4345, dtype: object
# radius                         1
# x                            729
# x_max                        730
# x_min                        729
# y                           2902
# y_max                       2903
# y_min                       2902
# z                              0
# z_max                          1
# z_min                          0
# features                    4346
# xc                    9.1239e-05
# yc                   7.25681e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4346, dtype: object
# radius                         1
# x                              4
# x_max                          5
# x_min                          4
# y                           2742
# y_max                       2743
# y_min                       2742
# z                              0
# z_max                          1
# z_min                          0
# features                    4347
# xc                   5.00626e-07
# yc                   6.85671e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4347, dtype: object
# radius                         1
# x                            625
# x_max                        626
# x_min                        625
# y                           2551
# y_max                       2552
# y_min                       2551
# z                              0
# z_max                          1
# z_min                          0
# features                    4348
# xc                   7.82228e-05
# yc                   6.37909e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4348, dtype: object
# radius                         1
# x                            627
# x_max                        628
# x_min                        627
# y                           2546
# y_max                       2547
# y_min                       2546
# z                              0
# z_max                          1
# z_min                          0
# features                    4349
# xc                   7.84731e-05
# yc                   6.36659e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4349, dtype: object
# radius                         1
# x                            624
# x_max                        625
# x_min                        624
# y                           2545
# y_max                       2546
# y_min                       2545
# z                              0
# z_max                          1
# z_min                          0
# features                    4350
# xc                   7.80976e-05
# yc                   6.36409e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4350, dtype: object
# radius                         1
# x                            613
# x_max                        614
# x_min                        613
# y                           2533
# y_max                       2534
# y_min                       2533
# z                              0
# z_max                          1
# z_min                          0
# features                    4351
# xc                   7.67209e-05
# yc                   6.33408e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4351, dtype: object
# radius                         1
# x                            619
# x_max                        620
# x_min                        619
# y                           2529
# y_max                       2530
# y_min                       2529
# z                              0
# z_max                          1
# z_min                          0
# features                    4352
# xc                   7.74718e-05
# yc                   6.32408e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4352, dtype: object
# radius                         1
# x                            617
# x_max                        618
# x_min                        617
# y                           2527
# y_max                       2528
# y_min                       2527
# z                              0
# z_max                          1
# z_min                          0
# features                    4353
# xc                   7.72215e-05
# yc                   6.31908e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4353, dtype: object
# radius                         1
# x                            607
# x_max                        608
# x_min                        607
# y                           2522
# y_max                       2523
# y_min                       2522
# z                              0
# z_max                          1
# z_min                          0
# features                    4354
# xc                     7.597e-05
# yc                   6.30658e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4354, dtype: object
# radius                         1
# x                            322
# x_max                        323
# x_min                        322
# y                           2406
# y_max                       2407
# y_min                       2406
# z                              0
# z_max                          1
# z_min                          0
# features                    4355
# xc                   4.03004e-05
# yc                    6.0165e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4355, dtype: object
# radius                         1
# x                            276
# x_max                        277
# x_min                        276
# y                           1818
# y_max                       1819
# y_min                       1818
# z                              0
# z_max                          1
# z_min                          0
# features                    4356
# xc                   3.45432e-05
# yc                   4.54614e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4356, dtype: object
# radius                         1
# x                            539
# x_max                        540
# x_min                        539
# y                           1731
# y_max                       1732
# y_min                       1731
# z                              0
# z_max                          1
# z_min                          0
# features                    4357
# xc                   6.74593e-05
# yc                   4.32858e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4357, dtype: object
# radius                         1
# x                            546
# x_max                        547
# x_min                        546
# y                           1724
# y_max                       1725
# y_min                       1724
# z                              0
# z_max                          1
# z_min                          0
# features                    4358
# xc                   6.83354e-05
# yc                   4.31108e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4358, dtype: object
# radius                         1
# x                            506
# x_max                        507
# x_min                        506
# y                           1123
# y_max                       1124
# y_min                       1123
# z                              0
# z_max                          1
# z_min                          0
# features                    4359
# xc                   6.33292e-05
# yc                    2.8082e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4359, dtype: object
# radius                         1
# x                            446
# x_max                        447
# x_min                        446
# y                           1004
# y_max                       1005
# y_min                       1004
# z                              0
# z_max                          1
# z_min                          0
# features                    4360
# xc                   5.58198e-05
# yc                   2.51063e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4360, dtype: object
# radius                         1
# x                            427
# x_max                        428
# x_min                        427
# y                            954
# y_max                        955
# y_min                        954
# z                              0
# z_max                          1
# z_min                          0
# features                    4361
# xc                   5.34418e-05
# yc                    2.3856e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4361, dtype: object
# radius                         1
# x                            141
# x_max                        142
# x_min                        141
# y                            820
# y_max                        821
# y_min                        820
# z                              0
# z_max                          1
# z_min                          0
# features                    4362
# xc                   1.76471e-05
# yc                   2.05051e-05
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4362, dtype: object
# radius                         1
# x                            512
# x_max                        513
# x_min                        512
# y                             59
# y_max                         60
# y_min                         59
# z                              0
# z_max                          1
# z_min                          0
# features                    4363
# xc                   6.40801e-05
# yc                   1.47537e-06
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4363, dtype: object
# radius                         1
# x                            497
# x_max                        498
# x_min                        497
# y                             44
# y_max                         45
# y_min                         44
# z                              0
# z_max                          1
# z_min                          0
# features                    4364
# xc                   6.22028e-05
# yc                   1.10028e-06
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4364, dtype: object
# radius                         1
# x                            486
# x_max                        487
# x_min                        486
# y                             42
# y_max                         43
# y_min                         42
# z                              0
# z_max                          1
# z_min                          0
# features                    4365
# xc                    6.0826e-05
# yc                   1.05026e-06
# zc                         5e-05
# target                       RFP
# distance                       0
# passes_thresholds           True
# Name: 4365, dtype: object

# %%
image.axis_labels(Axes.CH)
# Out:
# [0, 1, 2, 3]

# %%
data, axes = image.get_slice({Axes.CH: 1})

# %%
z_proj.to_multipage_tiff('/home/nomi/Desktop/sec3_ch2_clipped.tiff')
